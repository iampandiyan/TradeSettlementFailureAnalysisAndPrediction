# %%
import pandas as pd
from AnalysisUtils import AnalysisUtils
AnalysisUtilsObj=AnalysisUtils()

dataset=pd.read_csv('PreProcessedTradeSettlementDetails.csv')
dataset
# Out:
#      Trade ID Trade Type Instrument Type   Trade Value  Trade Volume  \
# 0      T00001        Buy          Equity  1.712199e+05          3256
# 1      T00002       Sell            Bond  1.043790e+06          9626
# 2      T00003        Buy      Derivative  2.320635e+06          9868
# 3      T00004        Buy      Derivative  4.900256e+05           187
# 4      T00005        Buy      Derivative  1.460759e+06          8275
# ...       ...        ...             ...           ...           ...
# 9995   T09996        Buy      Derivative  3.865635e+05           120
# 9996   T09997       Sell            Bond  7.483296e+04          7317
# 9997   T09998       Sell          Equity  1.215368e+06           510
# 9998   T09999       Sell          Equity  8.735853e+05          8422
# 9999   T10000        Buy            Bond  3.256045e+05           246
#
#      Counterparty ID  Counterparty Risk Score  Counterparty Failures  \
# 0              CP108                 0.018296                      2
# 1              CP192                 0.248703                      2
# 2              CP474                 0.640106                      1
# 3              CP205                 0.542102                      4
# 4               CP61                 0.056382                      1
# ...              ...                      ...                    ...
# 9995           CP261                 0.378298                      7
# 9996            CP74                 0.121223                      8
# 9997           CP425                 0.895436                      0
# 9998           CP126                 0.366819                      1
# 9999            CP95                 0.964127                      8
#
#      Settlement Status   Settlement Failure Reason  ...  Time to Settle  \
# 0              Success                        NONE  ...       35.993201
# 1              Success                        NONE  ...       65.124897
# 2              Success                        NONE  ...       53.515460
# 3              Success                        NONE  ...       39.627149
# 4              Success                        NONE  ...       50.762670
# ...                ...                         ...  ...             ...
# 9995           Success                        NONE  ...       48.779840
# 9996           Success                        NONE  ...       44.925273
# 9997              Fail  Client Instruction Missing  ...       29.695967
# 9998           Success                        NONE  ...       54.585931
# 9999           Success                        NONE  ...       62.117103
#
#       Counterparty Failure Rate  Currency  Settlement Type  Client ID  \
# 0                          0.02       USD              AoP      CL260
# 1                          0.02       USD              AoP      CL221
# 2                          0.01       JPY              AoP       CL15
# 3                          0.04       EUR              FoP       CL36
# 4                          0.01       GBP              AoP       CL34
# ...                         ...       ...              ...        ...
# 9995                       0.07       INR              AoP      CL179
# 9996                       0.08       GBP              FoP      CL257
# 9997                       0.00       JPY              FoP      CL226
# 9998                       0.01       JPY              FoP      CL123
# 9999                       0.08       JPY              FoP      CL255
#
#             ISIN  Trade Matched or Not Expected Settlement Date  \
# 0     INE000062D               Matched               2024-06-06
# 1     INE000042U               Matched               2024-08-06
# 2     INE000031V               Matched               2024-11-07
# 3     INE000052D               Matched               2024-10-27
# 4     INE000060S               Matched               2024-11-28
# ...          ...                   ...                      ...
# 9995  INE000092C               Matched               2024-12-04
# 9996  INE000095D               Matched               2024-01-07
# 9997  INE000080Q               Matched               2024-12-23
# 9998  INE000080Q               Matched               2024-03-17
# 9999  INE000014D               Matched               2024-09-29
#
#      Actual Settlement Date Days Difference
# 0                2024-06-06               0
# 1                2024-08-06               0
# 2                2024-11-07               0
# 3                2024-10-27               0
# 4                2024-11-28               0
# ...                     ...             ...
# 9995             2024-12-04               0
# 9996             2024-01-07               0
# 9997             2024-12-27               4
# 9998             2024-03-17               0
# 9999             2024-09-29               0
#
# [10000 rows x 25 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Trade ID                   10000 non-null  object
#  1   Trade Type                 10000 non-null  object
#  2   Instrument Type            10000 non-null  object
#  3   Trade Value                10000 non-null  float64
#  4   Trade Volume               10000 non-null  int64
#  5   Counterparty ID            10000 non-null  object
#  6   Counterparty Risk Score    10000 non-null  float64
#  7   Counterparty Failures      10000 non-null  int64
#  8   Settlement Status          10000 non-null  object
#  9   Settlement Failure Reason  10000 non-null  object
#  10  Settlement Duration        10000 non-null  float64
#  11  Market Volatility          10000 non-null  float64
#  12  Liquidity                  10000 non-null  float64
#  13  Processing Time            10000 non-null  int64
#  14  Manual Intervention        10000 non-null  int64
#  15  Time to Settle             10000 non-null  float64
#  16  Counterparty Failure Rate  10000 non-null  float64
#  17  Currency                   10000 non-null  object
#  18  Settlement Type            10000 non-null  object
#  19  Client ID                  10000 non-null  object
#  20  ISIN                       10000 non-null  object
#  21  Trade Matched or Not       10000 non-null  object
#  22  Expected Settlement Date   10000 non-null  object
#  23  Actual Settlement Date     10000 non-null  object
#  24  Days Difference            10000 non-null  int64
# dtypes: float64(7), int64(5), object(13)
# memory usage: 1.9+ MB

# %%
dataset.isna().sum()
# Out:
# Trade ID                     0
# Trade Type                   0
# Instrument Type              0
# Trade Value                  0
# Trade Volume                 0
# Counterparty ID              0
# Counterparty Risk Score      0
# Counterparty Failures        0
# Settlement Status            0
# Settlement Failure Reason    0
# Settlement Duration          0
# Market Volatility            0
# Liquidity                    0
# Processing Time              0
# Manual Intervention          0
# Time to Settle               0
# Counterparty Failure Rate    0
# Currency                     0
# Settlement Type              0
# Client ID                    0
# ISIN                         0
# Trade Matched or Not         0
# Expected Settlement Date     0
# Actual Settlement Date       0
# Days Difference              0
# dtype: int64

# %%
dataset['Settlement Status'].value_counts()
# Out:
# Settlement Status
# Success    9038
# Fail        962
# Name: count, dtype: int64

# %%
#from pandas_profiling import ProfileReport

# %%
quan, qual=AnalysisUtilsObj.quanQual(dataset)
quan
# Out:
# ['Trade Value',
#  'Trade Volume',
#  'Counterparty Risk Score',
#  'Counterparty Failures',
#  'Settlement Duration',
#  'Market Volatility',
#  'Liquidity',
#  'Processing Time',
#  'Manual Intervention',
#  'Time to Settle',
#  'Counterparty Failure Rate',
#  'Days Difference']

# %%
qual
# Out:
# ['Trade ID',
#  'Trade Type',
#  'Instrument Type',
#  'Counterparty ID',
#  'Settlement Status',
#  'Settlement Failure Reason',
#  'Currency',
#  'Settlement Type',
#  'Client ID',
#  'ISIN',
#  'Trade Matched or Not',
#  'Expected Settlement Date',
#  'Actual Settlement Date']

# %%
print(dataset.describe(include='all'))
# Out:
#        Trade ID Trade Type Instrument Type   Trade Value  Trade Volume  \
# count     10000      10000           10000  1.000000e+04  10000.000000
# unique    10000          2               3           NaN           NaN
# top      T00001       Sell            Bond           NaN           NaN
# freq          1       5031            3391           NaN           NaN
# mean        NaN        NaN             NaN  7.331874e+05   4952.684900
# std         NaN        NaN             NaN  9.340539e+05   2915.346447
# min         NaN        NaN             NaN  8.615470e+03      1.000000
# 25%         NaN        NaN             NaN  2.241557e+05   2373.750000
# 50%         NaN        NaN             NaN  4.552612e+05   4922.500000
# 75%         NaN        NaN             NaN  8.774353e+05   7458.250000
# max         NaN        NaN             NaN  2.486141e+07   9999.000000
#
#        Counterparty ID  Counterparty Risk Score  Counterparty Failures  \
# count            10000             10000.000000           10000.000000
# unique             499                      NaN                    NaN
# top              CP329                      NaN                    NaN
# freq                34                      NaN                    NaN
# mean               NaN                 0.497356               4.518200
# std                NaN                 0.289897               2.892491
# min                NaN                 0.000006               0.000000
# 25%                NaN                 0.245372               2.000000
# 50%                NaN                 0.493194               5.000000
# 75%                NaN                 0.749218               7.000000
# max                NaN                 0.999945               9.000000
#
#        Settlement Status Settlement Failure Reason  ...  Time to Settle  \
# count              10000                     10000  ...    10000.000000
# unique                 2                        14  ...             NaN
# top              Success                      NONE  ...             NaN
# freq                9038                      9038  ...             NaN
# mean                 NaN                       NaN  ...       47.488184
# std                  NaN                       NaN  ...       10.377724
# min                  NaN                       NaN  ...        7.062265
# 25%                  NaN                       NaN  ...       40.547895
# 50%                  NaN                       NaN  ...       47.410759
# 75%                  NaN                       NaN  ...       54.389228
# max                  NaN                       NaN  ...       85.105469
#
#         Counterparty Failure Rate  Currency  Settlement Type  Client ID  \
# count                10000.000000     10000            10000      10000
# unique                        NaN         5                2        299
# top                           NaN       GBP              AoP      CL169
# freq                          NaN      2046             5121         50
# mean                     0.045182       NaN              NaN        NaN
# std                      0.028925       NaN              NaN        NaN
# min                      0.000000       NaN              NaN        NaN
# 25%                      0.020000       NaN              NaN        NaN
# 50%                      0.050000       NaN              NaN        NaN
# 75%                      0.070000       NaN              NaN        NaN
# max                      0.090000       NaN              NaN        NaN
#
#               ISIN  Trade Matched or Not Expected Settlement Date  \
# count        10000                 10000                    10000
# unique         100                     2                      365
# top     INE0000639               Matched               2024-07-07
# freq           124                  9530                       41
# mean           NaN                   NaN                      NaN
# std            NaN                   NaN                      NaN
# min            NaN                   NaN                      NaN
# 25%            NaN                   NaN                      NaN
# 50%            NaN                   NaN                      NaN
# 75%            NaN                   NaN                      NaN
# max            NaN                   NaN                      NaN
#
#        Actual Settlement Date Days Difference
# count                   10000    10000.000000
# unique                    368             NaN
# top                2024-12-30             NaN
# freq                       43             NaN
# mean                      NaN        0.288900
# std                       NaN        0.993346
# min                       NaN        0.000000
# 25%                       NaN        0.000000
# 50%                       NaN        0.000000
# 75%                       NaN        0.000000
# max                       NaN        5.000000
#
# [11 rows x 25 columns]

# %%
AnalysisUtilsObj.createDescriptiveTable(dataset)
# Out:
#                   Trade Value    Trade Volume Counterparty Risk Score  \
# Mean              733187.3669       4952.6849                0.497356
# Median          455261.153718          4922.5                0.493194
# Mode               8615.47033             201                0.000006
# Q1:25%          224155.694433         2373.75                0.245372
# Q2:50%          455261.153718          4922.5                0.493194
# Q3:75%          877435.264598         7458.25                0.749218
# 99%                       NaN             NaN                     NaN
# Q4:100%       24861406.517088          9999.0                0.999945
# IQR             653279.570165          5084.5                0.503846
# 1.5rule         979919.355247         7626.75                0.755769
# Lesser         -755763.660814         -5253.0               -0.510397
# Greater        1857354.619845         15085.0                1.504986
# Min                8615.47033               1                0.000006
# Max           24861406.517088            9999                0.999945
# Kurtosis            73.675387       -1.217636               -1.207935
# Skew                 5.629372        0.033423                0.018543
# Var       872456674460.514893  8499244.906503                 0.08404
# Std             934053.892696     2915.346447                0.289897
# 99              4403309.41729         9910.01                0.988754
#
#          Counterparty Failures Settlement Duration Market Volatility  \
# Mean                    4.5182           48.002084          0.300382
# Median                     5.0           48.045218          0.300378
# Mode                         8           12.062265           0.10015
# Q1:25%                     2.0           41.292871          0.201696
# Q2:50%                     5.0           48.045218          0.300378
# Q3:75%                     7.0            54.59569          0.400195
# 99%                        NaN                 NaN               NaN
# Q4:100%                    9.0           87.036332          0.499999
# IQR                        5.0           13.302819          0.198498
# 1.5rule                    7.5           19.954229          0.297747
# Lesser                    -5.5           21.338642         -0.096051
# Greater                   14.5           74.549918          0.697942
# Min                          0           12.062265           0.10015
# Max                          9           87.036332          0.499999
# Kurtosis             -1.242217           -0.000061         -1.193091
# Skew                 -0.008995           -0.002087         -0.011514
# Var                   8.366505           99.799154           0.01316
# Std                   2.892491            9.989953          0.114716
# 99                         9.0           71.314174          0.495201
#
#          Liquidity Processing Time Manual Intervention Time to Settle  \
# Mean      0.054773         29.8482              0.2901      47.488184
# Median    0.054927            30.0                 0.0      47.410759
# Mode          0.01              29                   0       7.062265
# Q1:25%    0.032068            15.0                 0.0      40.547895
# Q2:50%    0.054927            30.0                 0.0      47.410759
# Q3:75%    0.077043            44.0                 1.0      54.389228
# 99%            NaN             NaN                 NaN            NaN
# Q4:100%   0.099993            59.0                 1.0      85.105469
# IQR       0.044975            29.0                 1.0      13.841333
# 1.5rule   0.067462            43.5                 1.5         20.762
# Lesser   -0.035394           -28.5                -1.5      19.785895
# Greater   0.144504            87.5                 2.5      75.151227
# Min           0.01               1                   0       7.062265
# Max       0.099993              59                   1      85.105469
# Kurtosis -1.202813       -1.191281           -1.144236       0.022597
# Skew     -0.006514         0.01771            0.925199       0.003508
# Var       0.000672      287.471104            0.205963     107.697161
# Std       0.025918       16.954973            0.453831      10.377724
# 99        0.099136            59.0                 1.0      71.957482
#
#          Counterparty Failure Rate Days Difference
# Mean                      0.045182          0.2889
# Median                        0.05             0.0
# Mode                          0.08               0
# Q1:25%                        0.02             0.0
# Q2:50%                        0.05             0.0
# Q3:75%                        0.07             0.0
# 99%                            NaN             NaN
# Q4:100%                       0.09             5.0
# IQR                           0.05             0.0
# 1.5rule                      0.075             0.0
# Lesser                      -0.055             0.0
# Greater                      0.145             0.0
# Min                            0.0               0
# Max                           0.09               5
# Kurtosis                 -1.242217       12.266687
# Skew                     -0.008995        3.621348
# Var                       0.000837        0.986735
# Std                       0.028925        0.993346
# 99                            0.09             5.0

# %%
lesserOutlier,greaterOutlier=AnalysisUtilsObj.getOutliers(dataset)

# %%
print(lesserOutlier)
print(greaterOutlier)
# Out:
# ['Settlement Duration', 'Time to Settle']
# ['Trade Value', 'Settlement Duration', 'Time to Settle', 'Days Difference']

# %%
AnalysisUtilsObj.removeOutlier(dataset)

# %%
lesserOutlier,greaterOutlier=AnalysisUtilsObj.getOutliers(dataset)

# %%
print(lesserOutlier)
print(greaterOutlier)
# Out:
# []
# []

# %%
dataset.corr(numeric_only=True)
# Out:
#                            Trade Value  Trade Volume  Counterparty Risk Score  \
# Trade Value                   1.000000      0.001121                 0.003593
# Trade Volume                  0.001121      1.000000                 0.001940
# Counterparty Risk Score       0.003593      0.001940                 1.000000
# Counterparty Failures         0.010489      0.018703                -0.008706
# Settlement Duration          -0.001570      0.012976                -0.013241
# Market Volatility             0.000504     -0.015385                -0.009593
# Liquidity                    -0.006738     -0.003777                -0.003605
# Processing Time               0.004018     -0.001943                -0.006375
# Manual Intervention          -0.006008      0.012834                -0.009544
# Time to Settle                0.000357      0.010523                -0.015788
# Counterparty Failure Rate     0.010489      0.018703                -0.008706
# Days Difference                    NaN           NaN                      NaN
#
#                            Counterparty Failures  Settlement Duration  \
# Trade Value                             0.010489            -0.001570
# Trade Volume                            0.018703             0.012976
# Counterparty Risk Score                -0.008706            -0.013241
# Counterparty Failures                   1.000000            -0.016421
# Settlement Duration                    -0.016421             1.000000
# Market Volatility                      -0.011819             0.000799
# Liquidity                               0.003179             0.000930
# Processing Time                         0.005252             0.010467
# Manual Intervention                    -0.003146             0.001948
# Time to Settle                         -0.016931             0.960948
# Counterparty Failure Rate               1.000000            -0.016421
# Days Difference                              NaN                  NaN
#
#                            Market Volatility  Liquidity  Processing Time  \
# Trade Value                         0.000504  -0.006738         0.004018
# Trade Volume                       -0.015385  -0.003777        -0.001943
# Counterparty Risk Score            -0.009593  -0.003605        -0.006375
# Counterparty Failures              -0.011819   0.003179         0.005252
# Settlement Duration                 0.000799   0.000930         0.010467
# Market Volatility                   1.000000   0.002530         0.001144
# Liquidity                           0.002530   1.000000         0.016218
# Processing Time                     0.001144   0.016218         1.000000
# Manual Intervention                -0.023049  -0.001841        -0.000489
# Time to Settle                      0.001317   0.002933         0.013171
# Counterparty Failure Rate          -0.011819   0.003179         0.005252
# Days Difference                          NaN        NaN              NaN
#
#                            Manual Intervention  Time to Settle  \
# Trade Value                          -0.006008        0.000357
# Trade Volume                          0.012834        0.010523
# Counterparty Risk Score              -0.009544       -0.015788
# Counterparty Failures                -0.003146       -0.016931
# Settlement Duration                   0.001948        0.960948
# Market Volatility                    -0.023049        0.001317
# Liquidity                            -0.001841        0.002933
# Processing Time                      -0.000489        0.013171
# Manual Intervention                   1.000000        0.006758
# Time to Settle                        0.006758        1.000000
# Counterparty Failure Rate            -0.003146       -0.016931
# Days Difference                            NaN             NaN
#
#                            Counterparty Failure Rate  Days Difference
# Trade Value                                 0.010489              NaN
# Trade Volume                                0.018703              NaN
# Counterparty Risk Score                    -0.008706              NaN
# Counterparty Failures                       1.000000              NaN
# Settlement Duration                        -0.016421              NaN
# Market Volatility                          -0.011819              NaN
# Liquidity                                   0.003179              NaN
# Processing Time                             0.005252              NaN
# Manual Intervention                        -0.003146              NaN
# Time to Settle                             -0.016931              NaN
# Counterparty Failure Rate                   1.000000              NaN
# Days Difference                                  NaN              NaN

# %% [markdown]
# # Test the Analysis of Variance between Processing Time and Trade Volum at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
#One Way Classification
import scipy.stats as stats
f_statistic,p_value=stats.f_oneway(dataset['Processing Time'],dataset['Trade Volume'])
print("F-statistic:", f_statistic)
print("p-value:", p_value)
H0='There is no significance difference between the Processing Time and Trade Volume'
H1='There is a significance difference between  the Processing Time and Trade Volume'
if p_value < 0.05:
    print(H1)
else:
    print(H0)
# Out:
# F-statistic: 28512.534688045194
# p-value: 0.0
# There is a significance difference between  the Processing Time and Trade Volume

# %% [markdown]
# # Test the similarity between the Settlement Status(Failure) and Settlement Failure Reason(Client Instruction MissingR) with respect to Processing Time at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
ss=dataset[dataset['Settlement Status']=='Fail']['Processing Time']
sfr=dataset[dataset['Settlement Failure Reason']=='Client Instruction Missing']['Processing Time']
stat,pval=ttest_ind(ss,sfr)
print(stat)
print(pval)
H0='There is no similarity between the Settlement Status(Fail) and Settlement Failure Reason(Client Instruction Missing) with respect to Processing Time at significance level of 5%'
H1='There is similarity between the Settlement Status(Fail) and Settlement Failure Reason(Client Instruction Missing) with respect to Processing Time at significance level of 5%'
if(pval<0.05):
    print(H1)
else:
    print(H0)
# Out:
# -0.24968320987330433
# 0.8028816980258007
# There is no similarity between the Settlement Status(Fail) and Settlement Failure Reason(Client Instruction Missing) with respect to Processing Time at significance level of 5%
