# %%
import pandas as pd
from AnalysisUtils import AnalysisUtils
AnalysisUtilsObj=AnalysisUtils()

dataset=pd.read_csv('PreProcessedTradeSettlementDetails.csv')
dataset
# Out:
#      Trade ID Trade Type Instrument Type   Trade Value  Trade Volume  \
# 0      T00001        Buy      Derivative  3.015961e+05          9864
# 1      T00002       Sell          Equity  9.563089e+04           393
# 2      T00003       Sell      Derivative  2.612242e+06           746
# 3      T00004       Sell      Derivative  3.752272e+05          2431
# 4      T00005        Buy      Derivative  7.555690e+05          6134
# ...       ...        ...             ...           ...           ...
# 9995   T09996       Sell      Derivative  4.608977e+04          9386
# 9996   T09997       Sell            Bond  9.346820e+04          7995
# 9997   T09998        Buy      Derivative  1.636770e+05          1004
# 9998   T09999        Buy      Derivative  1.122020e+06          1835
# 9999   T10000       Sell      Derivative  1.104991e+06          3288
#
#      Counterparty ID  Counterparty Risk Score  Counterparty Failures  \
# 0              CP104                 0.072800                      4
# 1              CP203                 0.279677                      5
# 2              CP253                 0.662217                      8
# 3              CP387                 0.327795                      6
# 4              CP130                 0.584331                      2
# ...              ...                      ...                    ...
# 9995           CP180                 0.645849                      5
# 9996           CP404                 0.945889                      7
# 9997           CP241                 0.790618                      3
# 9998           CP442                 0.356010                      4
# 9999            CP51                 0.876496                      8
#
#      Settlement Status   Settlement Failure Reason  ...  Liquidity  \
# 0              Success                        NONE  ...   0.096471
# 1              Success                        NONE  ...   0.073714
# 2              Success                        NONE  ...   0.045369
# 3              Success                        NONE  ...   0.059105
# 4                 Fail  Client Instruction Missing  ...   0.065834
# ...                ...                         ...  ...        ...
# 9995           Success                        NONE  ...   0.078864
# 9996           Success                        NONE  ...   0.084594
# 9997              Fail     Client Short to Deliver  ...   0.044851
# 9998           Success                        NONE  ...   0.059820
# 9999           Success                        NONE  ...   0.034044
#
#       Processing Time  Manual Intervention  Time to Settle  \
# 0                  53                    1       28.936848
# 1                  23                    0       42.682706
# 2                  54                    0       50.157250
# 3                  34                    0       57.936072
# 4                  36                    0       55.297385
# ...               ...                  ...             ...
# 9995               57                    0       47.597210
# 9996               37                    1       31.998225
# 9997               23                    0       54.463287
# 9998               54                    0       65.618347
# 9999                4                    1       51.940747
#
#       Counterparty Failure Rate  Currency  Settlement Type Client ID  \
# 0                          0.04       INR              AoP      CL30
# 1                          0.05       INR              AoP      CL21
# 2                          0.08       EUR              FoP     CL276
# 3                          0.06       JPY              AoP     CL253
# 4                          0.02       INR              AoP     CL259
# ...                         ...       ...              ...       ...
# 9995                       0.05       USD              FoP     CL239
# 9996                       0.07       GBP              FoP     CL126
# 9997                       0.03       GBP              AoP      CL59
# 9998                       0.04       INR              FoP      CL20
# 9999                       0.08       GBP              FoP     CL225
#
#             ISIN Trade Matched or Not
# 0     INE000014D              Matched
# 1     INE0000223              Matched
# 2     INE000038D              Matched
# 3     INE000099U              Matched
# 4     INE000038D          Not Matched
# ...          ...                  ...
# 9995  INE000069C              Matched
# 9996  INE000029J              Matched
# 9997  INE000064J              Matched
# 9998  INE000053A              Matched
# 9999  INE000036V              Matched
#
# [10000 rows x 22 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Trade ID                   10000 non-null  object
#  1   Trade Type                 10000 non-null  object
#  2   Instrument Type            10000 non-null  object
#  3   Trade Value                10000 non-null  float64
#  4   Trade Volume               10000 non-null  int64
#  5   Counterparty ID            10000 non-null  object
#  6   Counterparty Risk Score    10000 non-null  float64
#  7   Counterparty Failures      10000 non-null  int64
#  8   Settlement Status          10000 non-null  object
#  9   Settlement Failure Reason  10000 non-null  object
#  10  Settlement Duration        10000 non-null  float64
#  11  Market Volatility          10000 non-null  float64
#  12  Liquidity                  10000 non-null  float64
#  13  Processing Time            10000 non-null  int64
#  14  Manual Intervention        10000 non-null  int64
#  15  Time to Settle             10000 non-null  float64
#  16  Counterparty Failure Rate  10000 non-null  float64
#  17  Currency                   10000 non-null  object
#  18  Settlement Type            10000 non-null  object
#  19  Client ID                  10000 non-null  object
#  20  ISIN                       10000 non-null  object
#  21  Trade Matched or Not       10000 non-null  object
# dtypes: float64(7), int64(4), object(11)
# memory usage: 1.7+ MB

# %%
dataset.isna().sum()
# Out:
# Trade ID                     0
# Trade Type                   0
# Instrument Type              0
# Trade Value                  0
# Trade Volume                 0
# Counterparty ID              0
# Counterparty Risk Score      0
# Counterparty Failures        0
# Settlement Status            0
# Settlement Failure Reason    0
# Settlement Duration          0
# Market Volatility            0
# Liquidity                    0
# Processing Time              0
# Manual Intervention          0
# Time to Settle               0
# Counterparty Failure Rate    0
# Currency                     0
# Settlement Type              0
# Client ID                    0
# ISIN                         0
# Trade Matched or Not         0
# dtype: int64

# %%
dataset['Settlement Status'].value_counts()
# Out:
# Settlement Status
# Success    8995
# Fail       1005
# Name: count, dtype: int64

# %%
#from pandas_profiling import ProfileReport

# %%
quan, qual=AnalysisUtilsObj.quanQual(dataset)
quan
# Out:
# ['Trade Value',
#  'Trade Volume',
#  'Counterparty Risk Score',
#  'Counterparty Failures',
#  'Settlement Duration',
#  'Market Volatility',
#  'Liquidity',
#  'Processing Time',
#  'Manual Intervention',
#  'Time to Settle',
#  'Counterparty Failure Rate']

# %%
qual
# Out:
# ['Trade ID',
#  'Trade Type',
#  'Instrument Type',
#  'Counterparty ID',
#  'Settlement Status',
#  'Settlement Failure Reason',
#  'Currency',
#  'Settlement Type',
#  'Client ID',
#  'ISIN',
#  'Trade Matched or Not']

# %%
print(dataset.describe(include='all'))
# Out:
#        Trade ID Trade Type Instrument Type   Trade Value  Trade Volume  \
# count     10000      10000           10000  1.000000e+04  10000.000000
# unique    10000          2               3           NaN           NaN
# top      T00001       Sell          Equity           NaN           NaN
# freq          1       5082            3377           NaN           NaN
# mean        NaN        NaN             NaN  7.337109e+05   4970.400600
# std         NaN        NaN             NaN  9.030039e+05   2912.175803
# min         NaN        NaN             NaN  1.045971e+04      1.000000
# 25%         NaN        NaN             NaN  2.224692e+05   2419.000000
# 50%         NaN        NaN             NaN  4.452190e+05   4945.500000
# 75%         NaN        NaN             NaN  8.826013e+05   7487.250000
# max         NaN        NaN             NaN  1.469020e+07   9998.000000
#
#        Counterparty ID  Counterparty Risk Score  Counterparty Failures  \
# count            10000             10000.000000           10000.000000
# unique             499                      NaN                    NaN
# top              CP239                      NaN                    NaN
# freq                36                      NaN                    NaN
# mean               NaN                 0.498898               4.493700
# std                NaN                 0.286675               2.879408
# min                NaN                 0.000148               0.000000
# 25%                NaN                 0.254700               2.000000
# 50%                NaN                 0.496763               5.000000
# 75%                NaN                 0.745566               7.000000
# max                NaN                 0.999960               9.000000
#
#        Settlement Status Settlement Failure Reason  ...     Liquidity  \
# count              10000                     10000  ...  10000.000000
# unique                 2                        14  ...           NaN
# top              Success                      NONE  ...           NaN
# freq                8995                      8995  ...           NaN
# mean                 NaN                       NaN  ...      0.054901
# std                  NaN                       NaN  ...      0.025841
# min                  NaN                       NaN  ...      0.010006
# 25%                  NaN                       NaN  ...      0.032418
# 50%                  NaN                       NaN  ...      0.055128
# 75%                  NaN                       NaN  ...      0.077096
# max                  NaN                       NaN  ...      0.099997
#
#         Processing Time  Manual Intervention  Time to Settle  \
# count      10000.000000         10000.000000    10000.000000
# unique              NaN                  NaN             NaN
# top                 NaN                  NaN             NaN
# freq                NaN                  NaN             NaN
# mean          30.108800             0.306000       47.398671
# std           16.983569             0.460853       10.529585
# min            1.000000             0.000000        9.788843
# 25%           15.000000             0.000000       40.155911
# 50%           30.000000             0.000000       47.360225
# 75%           45.000000             1.000000       54.502438
# max           59.000000             1.000000       95.208375
#
#         Counterparty Failure Rate  Currency  Settlement Type Client ID  \
# count                10000.000000     10000            10000     10000
# unique                        NaN         5                2       299
# top                           NaN       INR              FoP     CL169
# freq                          NaN      2021             5007        47
# mean                     0.044937       NaN              NaN       NaN
# std                      0.028794       NaN              NaN       NaN
# min                      0.000000       NaN              NaN       NaN
# 25%                      0.020000       NaN              NaN       NaN
# 50%                      0.050000       NaN              NaN       NaN
# 75%                      0.070000       NaN              NaN       NaN
# max                      0.090000       NaN              NaN       NaN
#
#               ISIN Trade Matched or Not
# count        10000                10000
# unique         100                    2
# top     INE0000390              Matched
# freq           133                 9497
# mean           NaN                  NaN
# std            NaN                  NaN
# min            NaN                  NaN
# 25%            NaN                  NaN
# 50%            NaN                  NaN
# 75%            NaN                  NaN
# max            NaN                  NaN
#
# [11 rows x 22 columns]

# %%
AnalysisUtilsObj.createDescriptiveTable(dataset)
# Out:
#                   Trade Value   Trade Volume Counterparty Risk Score  \
# Mean            733710.884923      4970.4006                0.498898
# Median          445218.983878         4945.5                0.496763
# Mode             10459.709868           1080                0.000148
# Q1:25%          222469.175878         2419.0                  0.2547
# Q2:50%          445218.983878         4945.5                0.496763
# Q3:75%          882601.320876        7487.25                0.745566
# 99%                       NaN            NaN                     NaN
# Q4:100%       14690199.104274         9998.0                 0.99996
# IQR             660132.144998        5068.25                0.490866
# 1.5rule         990198.217497       7602.375                0.736299
# Lesser         -767729.041618      -5183.375               -0.481599
# Greater        1872799.538373      15089.625                1.481865
# Min              10459.709868              1                0.000148
# Max           14690199.104274           9998                 0.99996
# Kurtosis            28.769624      -1.213715               -1.174662
# Skew                 4.033924       0.023764               -0.002235
# Var       815416039340.627075  8480767.90571                0.082183
# Std             903003.897744    2912.175803                0.286675
# 99             4459021.225092        9905.01                0.990168
#
#          Counterparty Failures Settlement Duration Market Volatility  \
# Mean                    4.4937           47.881771          0.299475
# Median                     5.0           47.887618          0.298541
# Mode                         1            9.349368          0.100036
# Q1:25%                     2.0           41.171661          0.198478
# Q2:50%                     5.0           47.887618          0.298541
# Q3:75%                     7.0           54.818526          0.401403
# 99%                        NaN                 NaN               NaN
# Q4:100%                    9.0           92.208375          0.499992
# IQR                        5.0           13.646865          0.202926
# 1.5rule                    7.5           20.470298          0.304389
# Lesser                    -5.5           20.701363         -0.105911
# Greater                   14.5           75.288825          0.705792
# Min                          0            9.349368          0.100036
# Max                          9           92.208375          0.499992
# Kurtosis             -1.235316            0.083196          -1.20434
# Skew                 -0.004701           -0.019903          0.005995
# Var                   8.290989          102.360799          0.013442
# Std                   2.879408           10.117351          0.115941
# 99                         9.0           71.028562          0.496343
#
#          Liquidity Processing Time Manual Intervention Time to Settle  \
# Mean      0.054901         30.1088               0.306      47.398671
# Median    0.055128            30.0                 0.0      47.360225
# Mode      0.010006              51                   0       9.788843
# Q1:25%    0.032418            15.0                 0.0      40.155911
# Q2:50%    0.055128            30.0                 0.0      47.360225
# Q3:75%    0.077096            45.0                 1.0      54.502438
# 99%            NaN             NaN                 NaN            NaN
# Q4:100%   0.099997            59.0                 1.0      95.208375
# IQR       0.044678            30.0                 1.0      14.346527
# 1.5rule   0.067017            45.0                 1.5       21.51979
# Lesser   -0.034599           -30.0                -1.5      18.636121
# Greater   0.144112            90.0                 2.5      76.022228
# Min       0.010006               1                   0       9.788843
# Max       0.099997              59                   1      95.208375
# Kurtosis -1.192159       -1.183145           -1.291149       0.040642
# Skew     -0.004136       -0.001947            0.842086       0.012057
# Var       0.000668      288.441607            0.212385      110.87217
# Std       0.025841       16.983569            0.460853      10.529585
# 99        0.099123            59.0                 1.0      71.996563
#
#          Counterparty Failure Rate
# Mean                      0.044937
# Median                        0.05
# Mode                          0.01
# Q1:25%                        0.02
# Q2:50%                        0.05
# Q3:75%                        0.07
# 99%                            NaN
# Q4:100%                       0.09
# IQR                           0.05
# 1.5rule                      0.075
# Lesser                      -0.055
# Greater                      0.145
# Min                            0.0
# Max                           0.09
# Kurtosis                 -1.235316
# Skew                     -0.004701
# Var                       0.000829
# Std                       0.028794
# 99                            0.09

# %%
lesserOutlier,greaterOutlier=AnalysisUtilsObj.getOutliers(dataset)

# %%
print(lesserOutlier)
print(greaterOutlier)
# Out:
# ['Settlement Duration', 'Time to Settle']
# ['Trade Value', 'Settlement Duration', 'Time to Settle']

# %%
AnalysisUtilsObj.removeOutlier(dataset)

# %%
lesserOutlier,greaterOutlier=AnalysisUtilsObj.getOutliers(dataset)

# %%
print(lesserOutlier)
print(greaterOutlier)
# Out:
# []
# []

# %%
dataset.corr(numeric_only=True)
# Out:
#                            Trade Value  Trade Volume  Counterparty Risk Score  \
# Trade Value                   1.000000     -0.001824                 0.008030
# Trade Volume                 -0.001824      1.000000                -0.009263
# Counterparty Risk Score       0.008030     -0.009263                 1.000000
# Counterparty Failures        -0.004843      0.014213                -0.007605
# Settlement Duration           0.018573      0.012070                 0.008816
# Market Volatility             0.004824     -0.012567                 0.004280
# Liquidity                     0.018164     -0.011564                -0.010642
# Processing Time               0.001799      0.014184                 0.016530
# Manual Intervention           0.003399      0.001213                -0.001858
# Time to Settle                0.020524      0.011299                 0.008941
# Counterparty Failure Rate    -0.004843      0.014213                -0.007605
#
#                            Counterparty Failures  Settlement Duration  \
# Trade Value                            -0.004843             0.018573
# Trade Volume                            0.014213             0.012070
# Counterparty Risk Score                -0.007605             0.008816
# Counterparty Failures                   1.000000            -0.006159
# Settlement Duration                    -0.006159             1.000000
# Market Volatility                      -0.004948             0.015790
# Liquidity                              -0.009124            -0.004559
# Processing Time                        -0.005561             0.000832
# Manual Intervention                    -0.021534             0.005066
# Time to Settle                         -0.000568             0.961107
# Counterparty Failure Rate               1.000000            -0.006159
#
#                            Market Volatility  Liquidity  Processing Time  \
# Trade Value                         0.004824   0.018164         0.001799
# Trade Volume                       -0.012567  -0.011564         0.014184
# Counterparty Risk Score             0.004280  -0.010642         0.016530
# Counterparty Failures              -0.004948  -0.009124        -0.005561
# Settlement Duration                 0.015790  -0.004559         0.000832
# Market Volatility                   1.000000  -0.000297        -0.009700
# Liquidity                          -0.000297   1.000000         0.002884
# Processing Time                    -0.009700   0.002884         1.000000
# Manual Intervention                 0.008319  -0.015560        -0.020047
# Time to Settle                      0.018985  -0.001930         0.001268
# Counterparty Failure Rate          -0.004948  -0.009124        -0.005561
#
#                            Manual Intervention  Time to Settle  \
# Trade Value                           0.003399        0.020524
# Trade Volume                          0.001213        0.011299
# Counterparty Risk Score              -0.001858        0.008941
# Counterparty Failures                -0.021534       -0.000568
# Settlement Duration                   0.005066        0.961107
# Market Volatility                     0.008319        0.018985
# Liquidity                            -0.015560       -0.001930
# Processing Time                      -0.020047        0.001268
# Manual Intervention                   1.000000        0.004496
# Time to Settle                        0.004496        1.000000
# Counterparty Failure Rate            -0.021534       -0.000568
#
#                            Counterparty Failure Rate
# Trade Value                                -0.004843
# Trade Volume                                0.014213
# Counterparty Risk Score                    -0.007605
# Counterparty Failures                       1.000000
# Settlement Duration                        -0.006159
# Market Volatility                          -0.004948
# Liquidity                                  -0.009124
# Processing Time                            -0.005561
# Manual Intervention                        -0.021534
# Time to Settle                             -0.000568
# Counterparty Failure Rate                   1.000000
