# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import time
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt



def selectkbest(indep_X,dep_Y,n):
        test = SelectKBest(score_func=chi2, k=n)
        fit1= test.fit(indep_X,dep_Y)
        selectk_features = fit1.transform(indep_X)
        print('Feature Column List')
        print(test.get_feature_names_out())
        return selectk_features
    
def split_scalar(indep_X,dep_Y):
        X_train, X_test, y_train, y_test = train_test_split(indep_X, dep_Y, test_size = 0.25, random_state = 0)
        sc = StandardScaler()
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)    
        return X_train, X_test, y_train, y_test
    
 
def cm_prediction(classifier,X_test):
     y_pred = classifier.predict(X_test)
        
        # Making the Confusion Matrix
     from sklearn.metrics import confusion_matrix
     cm = confusion_matrix(y_test, y_pred)
        
     from sklearn.metrics import accuracy_score 
     from sklearn.metrics import classification_report 
        #from sklearn.metrics import confusion_matrix
        #cm = confusion_matrix(y_test, y_pred)
        
     Accuracy=accuracy_score(y_test, y_pred )
        
     report=classification_report(y_test, y_pred)
     return  classifier,Accuracy,report,X_test,y_test,cm

def logistic(X_train,y_train,X_test):       
        # Fitting K-NN to the Training set
        from sklearn.linear_model import LogisticRegression
        classifier = LogisticRegression(random_state = 0)
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm      
    
def svm_linear(X_train,y_train,X_test):
                
        from sklearn.svm import LinearSVC
        classifier = LinearSVC( random_state = 0)
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm
    
def svm_NL(X_train,y_train,X_test):
                
        from sklearn.svm import SVC
        classifier = SVC(kernel = 'rbf', random_state = 0)
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm
   
def Navie(X_train,y_train,X_test):       
        # Fitting K-NN to the Training set
        from sklearn.naive_bayes import GaussianNB
        classifier = GaussianNB()
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm         
    
    
def knn(X_train,y_train,X_test):
           
        # Fitting K-NN to the Training set
        from sklearn.neighbors import KNeighborsClassifier
        classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm
def Decision(X_train,y_train,X_test):
        
        # Fitting K-NN to the Training set
        from sklearn.tree import DecisionTreeClassifier
        classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm      


def random(X_train,y_train,X_test):
        
        # Fitting K-NN to the Training set
        from sklearn.ensemble import RandomForestClassifier
        classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
        classifier.fit(X_train, y_train)
        classifier,Accuracy,report,X_test,y_test,cm=cm_prediction(classifier,X_test)
        return  classifier,Accuracy,report,X_test,y_test,cm
    
def selectk_Classification(acclog,accsvml,accsvmnl,accknn,accnav,accdes,accrf): 
    
    dataframe=pd.DataFrame(index=['ChiSquare'],columns=['Logistic','SVMl','SVMnl','KNN','Navie','Decision','Random'])
    for number,idex in enumerate(dataframe.index): 
        dataframe.loc[idex,'Logistic']=acclog[number] 
        dataframe.loc[idex,'SVMl']=accsvml[number]
        dataframe.loc[idex,'SVMnl']=accsvmnl[number] 
        dataframe.loc[idex,'KNN']=accknn[number] 
        dataframe.loc[idex,'Navie']=accnav[number]
        dataframe.loc[idex,'Decision']=accdes[number]
        dataframe.loc[idex,'Random']=accrf[number]
    return dataframe

# %%
dataset=pd.read_csv("TradeSettlementDetails.csv",index_col=None)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Trade Value                       10000 non-null  float64
#  1   Trade Volume                      10000 non-null  int64
#  2   Counterparty ID                   10000 non-null  int64
#  3   Counterparty Risk Score           10000 non-null  float64
#  4   Counterparty Failures             10000 non-null  int64
#  5   Market Volatility                 10000 non-null  float64
#  6   Liquidity                         10000 non-null  float64
#  7   Manual Intervention               10000 non-null  int64
#  8   Counterparty Failure Rate         10000 non-null  float64
#  9   Client ID                         10000 non-null  int64
#  10  Trade Type_Sell                   10000 non-null  int64
#  11  Instrument Type_Derivative        10000 non-null  int64
#  12  Instrument Type_Equity            10000 non-null  int64
#  13  Settlement Status_Success         10000 non-null  int64
#  14  Currency_GBP                      10000 non-null  int64
#  15  Currency_INR                      10000 non-null  int64
#  16  Currency_JPY                      10000 non-null  int64
#  17  Currency_USD                      10000 non-null  int64
#  18  Settlement Type_FoP               10000 non-null  int64
#  19  ISIN_INE000001N                   10000 non-null  int64
#  20  ISIN_INE000002R                   10000 non-null  int64
#  21  ISIN_INE000003U                   10000 non-null  int64
#  22  ISIN_INE000004E                   10000 non-null  int64
#  23  ISIN_INE000005F                   10000 non-null  int64
#  24  ISIN_INE0000062                   10000 non-null  int64
#  25  ISIN_INE0000077                   10000 non-null  int64
#  26  ISIN_INE000008A                   10000 non-null  int64
#  27  ISIN_INE000009Z                   10000 non-null  int64
#  28  ISIN_INE000010T                   10000 non-null  int64
#  29  ISIN_INE000011H                   10000 non-null  int64
#  30  ISIN_INE000012L                   10000 non-null  int64
#  31  ISIN_INE0000131                   10000 non-null  int64
#  32  ISIN_INE000014X                   10000 non-null  int64
#  33  ISIN_INE000015I                   10000 non-null  int64
#  34  ISIN_INE000016C                   10000 non-null  int64
#  35  ISIN_INE0000176                   10000 non-null  int64
#  36  ISIN_INE000018D                   10000 non-null  int64
#  37  ISIN_INE000019H                   10000 non-null  int64
#  38  ISIN_INE0000201                   10000 non-null  int64
#  39  ISIN_INE000021M                   10000 non-null  int64
#  40  ISIN_INE000022P                   10000 non-null  int64
#  41  ISIN_INE000023W                   10000 non-null  int64
#  42  ISIN_INE000024D                   10000 non-null  int64
#  43  ISIN_INE000025H                   10000 non-null  int64
#  44  ISIN_INE000026S                   10000 non-null  int64
#  45  ISIN_INE0000276                   10000 non-null  int64
#  46  ISIN_INE000028L                   10000 non-null  int64
#  47  ISIN_INE000029O                   10000 non-null  int64
#  48  ISIN_INE000030F                   10000 non-null  int64
#  49  ISIN_INE000031G                   10000 non-null  int64
#  50  ISIN_INE0000324                   10000 non-null  int64
#  51  ISIN_INE000033Q                   10000 non-null  int64
#  52  ISIN_INE000034W                   10000 non-null  int64
#  53  ISIN_INE000035W                   10000 non-null  int64
#  54  ISIN_INE0000367                   10000 non-null  int64
#  55  ISIN_INE000037C                   10000 non-null  int64
#  56  ISIN_INE0000385                   10000 non-null  int64
#  57  ISIN_INE000039C                   10000 non-null  int64
#  58  ISIN_INE000040F                   10000 non-null  int64
#  59  ISIN_INE000041Y                   10000 non-null  int64
#  60  ISIN_INE000042J                   10000 non-null  int64
#  61  ISIN_INE000043S                   10000 non-null  int64
#  62  ISIN_INE000044J                   10000 non-null  int64
#  63  ISIN_INE000045O                   10000 non-null  int64
#  64  ISIN_INE0000461                   10000 non-null  int64
#  65  ISIN_INE000047I                   10000 non-null  int64
#  66  ISIN_INE0000487                   10000 non-null  int64
#  67  ISIN_INE000049X                   10000 non-null  int64
#  68  Trade Matched or Not_Not Matched  10000 non-null  int64
# dtypes: float64(5), int64(64)
# memory usage: 5.3 MB

# %%
indep_X=dataset.drop('Settlement Status_Success', axis=1)
dep_Y=dataset['Settlement Status_Success']
kbest=selectkbest(indep_X,dep_Y,10)
# Out:
# Feature Column List
# ['Trade Value' 'Trade Volume' 'Counterparty ID' 'Counterparty Failures'
#  'Counterparty Failure Rate' 'Client ID' 'ISIN_INE000010T'
#  'ISIN_INE0000201' 'ISIN_INE0000276' 'ISIN_INE000028L']

# %%
acclog=[]
accsvml=[]
accsvmnl=[]
accknn=[]
accnav=[]
accdes=[]
accrf=[]


X_train, X_test, y_train, y_test=split_scalar(kbest,dep_Y)   
    
        
classifier,Accuracy,report,X_test,y_test,cm=logistic(X_train,y_train,X_test)
acclog.append(Accuracy)

classifier,Accuracy,report,X_test,y_test,cm=svm_linear(X_train,y_train,X_test)  
accsvml.append(Accuracy)
    
classifier,Accuracy,report,X_test,y_test,cm=svm_NL(X_train,y_train,X_test)  
accsvmnl.append(Accuracy)
    
classifier,Accuracy,report,X_test,y_test,cm=knn(X_train,y_train,X_test)  
accknn.append(Accuracy)
    
classifier,Accuracy,report,X_test,y_test,cm=Navie(X_train,y_train,X_test)  
accnav.append(Accuracy)
    
classifier,Accuracy,report,X_test,y_test,cm=Decision(X_train,y_train,X_test)  
accdes.append(Accuracy)
    
classifier,Accuracy,report,X_test,y_test,cm=random(X_train,y_train,X_test)  
accrf.append(Accuracy)
    
result=selectk_Classification(acclog,accsvml,accsvmnl,accknn,accnav,accdes,accrf)

result
# Out:
#           Logistic    SVMl   SVMnl     KNN  Navie Decision  Random
# ChiSquare   0.7928  0.7992  0.7984  0.7768  0.724   0.7204  0.7588
